# %% [markdown]
# # Netflix Data Analysis Project
#
# ## Overview
# In this project I analyzed the Netflix titles dataset using Python, Pandas and SQL.
# The dataset contains 8807 Netflix titles with 12 columns including movies and TV shows
# from various countries around the world.
#
# ## Tools Used
# - Python
# - Pandas
# - NumPy
# - SQL (SQLite)
#
# ## Dataset Source
# Kaggle — Netflix Movies and TV Shows
# https://www.kaggle.com/datasets/shivamb/netflix-shows

# %% [markdown]
# ## Step 1: Importing Libraries
# Importing Pandas for data manipulation and NumPy for numerical operations

# %%
import pandas as pd
import numpy as np
print("Libraries Loaded Succesffuly")
# Out:
# Libraries Loaded Succesffuly

# %% [markdown]
# ###Mounting Drive to Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 2: Loading the Dataset
# Loading the Netflix CSV file and exploring its basic structure

# %%
file_path = "/content/drive/MyDrive/Dataset/netflix_titles.csv"
df = pd.read_csv(file_path)

print("Shape:", df.shape)
print("---")
print(df.head())
print("---")
print(df.info())
# Out:
# Shape: (8807, 12)
# ---
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Step 3: Data Cleaning
# Checking and handling missing values in the dataset.
#
# Missing values found:
# - director: 2634 missing
# - cast: 825 missing
# - country: 831 missing
# - date_added: 10 missing
# - rating: 4 missing
# - duration: 3 missing
#
# Strategy:
# - director, cast, country, rating → filled with "Unknown" / "Not Rated"
# - date_added, duration → dropped rows as these are important for analysis

# %%
# Check missing values
print(df.isnull().sum())

# Fix missing values
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')
df['rating'] = df['rating'].fillna('Not Rated')

# Drop rows with missing date and duration
df.dropna(subset=['date_added', 'duration'], inplace=True)

# Confirm
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# year_added        10
# dtype: int64
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# year_added      0
# dtype: int64

# %% [markdown]
# ## Step 4: Answering Business Questions
# Analyzing the data to extract meaningful insights

# %% [markdown]
# ### Q1: Movies vs TV Shows — Which is More on Netflix?

# %%
# Q1: Movies vs  TV shows Which is More?
print(df["type"].value_counts())
print(df['type'].value_counts(normalize=True)*100)
# Out:
# type
# Movie      6128
# TV Show    2666
# Name: count, dtype: int64
# type
# Movie      69.683875
# TV Show    30.316125
# Name: proportion, dtype: float64

# %% [markdown]
# ## Q1 Finding:
# ---
# Finding: Netflix has 6128 Movies (70%) and 2666 TV Shows (30%)
#
# Insight: Netflix focuses heavily on Movies rather than TV Shows.
# Nearly 70% of all content on Netflix is Movies.

# %% [markdown]
# ### Q2: Top 10 Countries Producing Most Content on Netflix?

# %%
filtered = df1[df1['country'] != 'Unknown']
print(filtered['country'].value_counts().head(10))
# Out:
# country
# United States     2809
# India              972
# Unknown            830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %% [markdown]
# ###  Q2 Finding:
# ---
# Finding: USA leads with 2809 titles followed by India with 972 titles
#
# Insight: USA produces 3x more content than India which is 2nd place.
# Emerging markets like Egypt and South Korea are also growing fast on Netflix.

# %% [markdown]
# ### Q3: Most Common Ratings on Netflix?

# %%
print(df['rating'].value_counts())
# Out:
# rating
# TV-MA        3205
# TV-14        2157
# TV-PG         861
# R             799
# PG-13         490
# TV-Y7         333
# TV-Y          306
# PG            287
# TV-G          220
# NR             79
# G              41
# TV-Y7-FV        6
# Not Rated       4
# NC-17           3
# UR              3
# Name: count, dtype: int64

# %% [markdown]
# ### Q3: Finding
# ---
# Finding: TV-MA is most common with 3205 titles followed by TV-14 with 2157 titles
#
# Insight: Over 60% of Netflix content targets mature audiences
# (TV-MA for 18+ and TV-14 for 14+).
# Children and family content is very limited on the platform.

# %% [markdown]
# ### Q4: How Much Content Was Added Each Year?

# %%
df['year_added'] = pd.to_datetime(df['date_added'], format = "mixed").dt.year
print(df['year_added'].value_counts().sort_index())
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      24
# 2015.0      82
# 2016.0     429
# 2017.0    1188
# 2018.0    1649
# 2019.0    2016
# 2020.0    1879
# 2021.0    1498
# Name: count, dtype: int64

# %% [markdown]
# ### Q4: How Much Content Was Added Each Year?
# ---
#
# Finding: Netflix grew slowly until 2016 then expanded rapidly
# Peak year was 2019 with 2016 titles added
# COVID-19 impacted content production in 2020 and 2021

# %% [markdown]
# ### Q5: Top 10 Most Frequent Directors on Netflix?

# %%
directors = df[df['director'] != 'Unknown']
print(directors['director'].value_counts().head(10))
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# ### Q5: Top 10 Most Frequent Directors?
# ---
# Finding: Rajiv Chilaka tops with 19 titles — mostly animated content
# Insight: High volume directors from India and Latin America
# dominate over famous Hollywood directors like Scorsese and Spielberg

# %% [markdown]
# ## Step 5: Data Visualization
# In this step we will create charts to visually represent our findings.
# Charts make it easier to communicate insights to clients.
#
# ### Loading Visualization Library
# Importing Matplotlib for creating charts and graphs

# %%
import matplotlib.pyplot as plt

print("Matplotlib loaded successfully!")
# Out:
# Matplotlib loaded successfully!

# %% [markdown]
# ### Chart 1: Movies vs TV Shows
# Visualizing the ratio of Movies vs TV Shows on Netflix

# %%
df['type'].value_counts().plot(kind='bar', color=['red','gray'])
plt.title('Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Chart 2: 'Distribution of Ratings on Netflix'

# %%
df['rating'].value_counts().head(10).plot(
    kind='barh',
    color='steelblue',
    edgecolor='white'
)
plt.title('Distribution of Ratings on Netflix')
plt.xlabel('Count')
plt.ylabel('Rating')
plt.grid(axis='x', color='gray', linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# ### Chart 3: Netflix Content Added Per Year
# Visualizing how Netflix grew its content library year by year

# %%
plt.figure(figsize=(12, 5))
df['year_added'].value_counts().sort_index().plot(kind='line', color='red')
plt.title('Netflix Content Added Per Year')
plt.xlabel('Year')
plt.ylabel('Content Added Pe Year')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Chart 4: Top 10 Countries by Netflix Content
# Visualizing which countries produce the most content on Netflix

# %%
filtered = df[df['country'] != 'Unknown']
filtered['country'].value_counts().head(10).plot(
    kind='barh',
    color='steelblue',
    edgecolor='white'
)
plt.title('Top 10 Countries by Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.grid(axis='x', color='gray', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Chart 5: Most Prolific Directors on Netflix
# Visualizing which directors have the most titles on Netflix

# %%
directors = df[df['director'] != 'Unknown']
directors['director'].value_counts().head(10).plot(
    kind='barh',
    color='steelblue',
    edgecolor='white'
)
plt.title('Most Prolific Directors on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Director')
plt.grid(axis='x', color='gray', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Step 6: SQL Practice
# In this step we will run SQL queries on our Netflix data
# using SQLite — a lightweight database built into Python
# No installation needed!

# %%
import sqlite3

# Create database in memory
conn = sqlite3.connect(':memory:')

# Load dataframe into SQL table
df.to_sql('netflix', conn, index=False)

print("Data loaded into SQL successfully!")
# Out:
# Data loaded into SQL successfully!

# %%
# Reload dataframe into SQL with year_added column
df.to_sql('netflix', conn, index=False, if_exists='replace')

print("Data reloaded successfully!")
# Out:
# Data reloaded successfully!

# %% [markdown]
# ### SQL Query 1: Movies vs TV Shows

# %%
query1 = pd.read_sql_query(
    """
    SELECT type, COUNT(*) AS total_count
    FROM netflix
    GROUP BY type
    """,
    conn
)
print(query1
)
# Out:
#       type  total_count
# 0    Movie         6131
# 1  TV Show         2676

# %% [markdown]
# ### SQL Query 2: Top 10 Countries by Content

# %%
query2 = pd.read_sql_query(
    """
    SELECT country, COUNT(*) AS total_count
    FROM netflix
    WHERE country != 'Unknown'
    GROUP BY country
    ORDER BY total_count DESC
    LIMIT 10
    """,
    conn
)

print(query2)
# Out:
#           country  total_count
# 0   United States         2818
# 1           India          972
# 2  United Kingdom          419
# 3           Japan          245
# 4     South Korea          199
# 5          Canada          181
# 6           Spain          145
# 7          France          124
# 8          Mexico          110
# 9           Egypt          106

# %% [markdown]
# ### SQL Query 3: Netflix Content Added Per Year

# %%
query3 = pd.read_sql_query(
    """
    SELECT year_added, COUNT(*) AS total_count
    FROM netflix
    WHERE year_added IS NOT NULL
    GROUP BY year_added
    ORDER BY year_added
    """,
    conn
)

print(query3)
# Out:
#     year_added  total_count
# 0       2008.0            2
# 1       2009.0            2
# 2       2010.0            1
# 3       2011.0           13
# 4       2012.0            3
# 5       2013.0           11
# 6       2014.0           24
# 7       2015.0           82
# 8       2016.0          429
# 9       2017.0         1188
# 10      2018.0         1649
# 11      2019.0         2016
# 12      2020.0         1879
# 13      2021.0         1498

# %% [markdown]
# ### SQL Query 4: Top 10 Countries by Content

# %%
query4 = pd.read_sql_query(
    """
    SELECT country, COUNT(*)  AS total_count
    FROM netflix
    WHERE country != 'Unknown'
    GROUP BY country
    ORDER BY total_count DESC
    """,
    conn
)
print(query4)
# Out:
#                                                country  total_count
# 0                                        United States         2818
# 1                                                India          972
# 2                                       United Kingdom          419
# 3                                                Japan          245
# 4                                          South Korea          199
# ..                                                 ...          ...
# 743                                  Argentina, France            1
# 744                             Argentina, Chile, Peru            1
# 745  Argentina, Brazil, France, Poland, Germany, De...            1
# 746                                      , South Korea            1
# 747                                  , France, Algeria            1
#
# [748 rows x 2 columns]

# %% [markdown]
# ### SQL Query 5: Most Prolific Directors on Netflix

# %%
query5 = pd.read_sql_query(
    """
    SELECT Director, COUNT(*) AS total_count
    FROM netflix
    WHERE director != 'Unknown'
    Group by Director
    Order by total_count DESC
    """,
    conn
)

print(query5)
# Out:
#                     director  total_count
# 0              Rajiv Chilaka           19
# 1     Raúl Campos, Jan Suter           18
# 2                Suhas Kadav           16
# 3               Marcus Raboy           16
# 4                  Jay Karas           14
# ...                      ...          ...
# 4523              Aamir Khan            1
# 4524            Aamir Bashir            1
# 4525         Aadish Keluskar            1
# 4526               A. Salaam            1
# 4527            A. Raajdheep            1
#
# [4528 rows x 2 columns]
